# %%
import pickle
loadStartupModal = pickle.load(open("startup_prediction_modal.sav", "rb"))

# %%
result = loadStartupModal.predict([[1234, 345, 5678, 0, 0]])
result
# Out:
# /Users/NYL9BJV/AI-Learning-Journey/my-ai-learning-lab/.venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[43566.28800262]])

# %%
rdInput = float(input("Give R&D value:"))
adminInput = float(input("Give Admin value:"))
marketingInput = float(input("Give Marketing value:"))
FloridaInput = int(input("Is this Florida:"))
NewYorkInput = int(input("Is this NewYork:"))

result = loadStartupModal.predict([[rdInput, adminInput, marketingInput, FloridaInput, NewYorkInput]])
print(f"Predicted Profit is {result}")
# Out:
# Give R&D value: 12000
# Give Admin value: 1200
# Give Marketing value: 12000
# Is this Florida: 0
# Is this NewYork: 1
# Predicted Profit is [[52607.16796101]]
# /Users/NYL9BJV/AI-Learning-Journey/my-ai-learning-lab/.venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
