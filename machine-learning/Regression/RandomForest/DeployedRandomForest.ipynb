# %%
import pickle
loadStartupModal = pickle.load(open("randomForest.sav", "rb"))

# %%
result = loadStartupModal.predict([[1234, 345, 5678, 0, 0]])
result
# Out:
# /Users/NYL9BJV/AI-Learning-Journey/my-ai-learning-lab/.venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([54474.8288])

# %%
rdInput = float(input("Give R&D value:"))
adminInput = float(input("Give Admin value:"))
marketingInput = float(input("Give Marketing value:"))
FloridaInput = int(input("Is this Florida:"))
NewYorkInput = int(input("Is this NewYork:"))

result = loadStartupModal.predict([[rdInput, adminInput, marketingInput, FloridaInput, NewYorkInput]])
print(f"Predicted Profit is {result}")
# Out:
# Give R&D value: 1020
# Give Admin value: 102
# Give Marketing value: 100
# Is this Florida: 0
# Is this NewYork: 0
# Predicted Profit is [52173.2532]
# /Users/NYL9BJV/AI-Learning-Journey/my-ai-learning-lab/.venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
