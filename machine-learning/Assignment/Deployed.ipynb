# %%
import pickle
loadStartupModal = pickle.load(open("randomForest.sav", "rb"))

# %%
result = loadStartupModal.predict([[30, 29.7, 1, 1, 1]])
result
# Out:
# /Users/NYL9BJV/AI-Learning-Journey/my-ai-learning-lab/.venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([22188.17716094])

# %%
age = float(input("Enter your age:"))
bmi = float(input("Enter your BMI:"))
numberOfChildren = float(input("Enter number of children:"))
gender = int(input("Enter your gender: male-1 or female-0:"))
smoker = int(input("Are you smoker: yes-1 or no-0:"))

result = loadStartupModal.predict([[age, bmi, numberOfChildren, gender, smoker]])
print(f"Predicted Insurance charge is {result}")
# Out:
# Enter your age: 30
# Enter your BMI: 29.7
# Enter number of children: 1
# Enter your gender: male-1 or female-0: 1
# Are you smoker: yes-1 or no-0: 1
# Predicted Insurance charge is [22188.17716094]
# /Users/NYL9BJV/AI-Learning-Journey/my-ai-learning-lab/.venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
