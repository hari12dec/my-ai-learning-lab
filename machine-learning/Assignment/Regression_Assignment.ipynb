# %%
#load dataset
import pandas as pd
givenDataSets = pd.read_csv("insurance_pre.csv")

# %%
givenDataSets = pd.get_dummies(givenDataSets, dtype=int, drop_first=True)
givenDataSets
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
#split input and output
givenDataSets.columns
independent = givenDataSets[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
dependent = givenDataSets[['charges']]

# %%
#split train set and test set
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(independent, dependent, test_size = 0.3, random_state = 42)

# %%
#identify the algorithm for model
# multi linear regression
# from sklearn.linear_model import LinearRegression
# regressor = LinearRegression()
# regressor.fit(X_train, Y_train)

# Support Vector Regression
# from sklearn.svm import SVR
# from sklearn.preprocessing import StandardScaler #scalar operation for better result

# sc = StandardScaler()
# X_train = sc.fit_transform(X_train)
# X_test = sc.transform(X_test)

# regressor  = SVR(kernel = 'sigmoid', C=1.0)
# regressor.fit(X_train, Y_train)

#Decision Tree
# from sklearn.tree import DecisionTreeRegressor

# # criterion=["squared_error", "friedman_mse", "absolute_error"]
# # splitter=["best", "random"]
# # max_features=["auto", "sqrt", "log2", None]

# regressor = DecisionTreeRegressor(
#     criterion='absolute_error',
#     splitter='random',
#     max_features='log2'
# )

# regressor = regressor.fit(X_train, Y_train)

# Y_predict = regressor.predict(X_test)

from sklearn.ensemble import RandomForestRegressor

regressor = RandomForestRegressor(
    criterion='absolute_error',   # or 'absolute_error', 'friedman_mse', 'poisson'
    n_estimators=1000,             # number of trees
    max_features='sqrt',         # or 'sqrt', 'log2', None, or an int/float
    random_state=0
)

regressor = regressor.fit(X_train, Y_train)

Y_predict = regressor.predict(X_test)
# Out:
# /Users/NYL9BJV/AI-Learning-Journey/my-ai-learning-lab/.venv/lib/python3.13/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)

# %%
#evaluate model with test dataset
Y_predict = regressor.predict(X_test) #model is predicting the value
#getitng score for predicted value, compare predicted value with actual test output
from sklearn.metrics import r2_score
r2_score = r2_score(Y_test, Y_predict)
r2_score #score nearby 1 is good model
# Out:
# 0.8565460834668501

# %%
import pickle
pickle.dump(regressor, open("randomForest.sav", "wb"))
