# %%
import pickle
deployedModel = pickle.load(open("svr.sav", "rb"))
result = deployedModel.predict([[1234, 345, 5678, 0, 0]])
# Out:
# /Users/NYL9BJV/AI-Learning-Journey/my-ai-learning-lab/.venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
rdInput = float(input("Give R&D value:"))
adminInput = float(input("Give Admin value:"))
marketingInput = float(input("Give Marketing value:"))
FloridaInput = int(input("Is this Florida:"))
NewYorkInput = int(input("Is this NewYork:"))

result = deployedModel.predict([[rdInput, adminInput, marketingInput, FloridaInput, NewYorkInput]])
print(f"Predicted Profit is {result}")
# Out:
# Give R&D value: 1002
# Give Admin value: 1002
# Give Marketing value: 102
# Is this Florida: 0
# Is this NewYork: 0
# Predicted Profit is [110008.59243485]
# /Users/NYL9BJV/AI-Learning-Journey/my-ai-learning-lab/.venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
