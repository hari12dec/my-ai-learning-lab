# %%
import pandas as pd
import numpy as np
import joblib
from Modeling import modelCreation
from Modeling import modelPrediction

# %%
BASE_PATH = "../data_collection/"
df = pd.read_csv(BASE_PATH + "prep_amazon_delivery_1.csv")

# %%
# Train model
modelCreation(df, "Delivery_Duration", "delivery_model")

# Sample input
sample = pd.DataFrame([{
    'Agent_Age': 30,
    'Agent_Rating': 4.5,
    'Traffic': 2,
    'distance_km': 5,
    'hour': 18,
    'is_peak': 1,
    'Weather_Sunny': 1,
    'Area_Urban': 1,
    'Category_Grocery': 1
}])

# Predict
result = modelPrediction("delivery_model", sample)

print("Predicted Delivery Duration:", result)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/AI-Learning-Journey/my-ai-learning-lab/.venv/lib/python3.13/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'hour'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 16
#       1 selected_features = [
#       2  'Agent_Age',
#       3  'Agent_Rating',
#    (...)     13  'Category_Grocery'
#      14 ]
# ---> 16 modelCreation(df, selected_features, "Delivery_Duration", "delivery_model")
#      18 sample = pd.DataFrame([{
#      19     'Agent_Age': 30,
#      20     'Agent_Rating': 4.5,
#    (...)     27     'Category_Grocery': 1
#      28 }])
#      30 result = modelPrediction("delivery_model", sample)
#
# File ~/AI-Learning-Journey/my-ai-learning-lab/ml-ds-capstone-project/model_creation/Modeling.py:16, in modelCreation(df, selected_features, target, model_name)
#      13 df = df.copy()
#      15 # 🔥 Feature Engineering
# ---> 16 df["hour_sin"] = np.sin(2 * np.pi * df["hour"] / 24)
#      17 df["dist_x_traffic"] = df["distance_km"] * df["Traffic"]
#      18 df["distance_x_peak"] = df["distance_km"] * df["is_peak"]
#
# File ~/AI-Learning-Journey/my-ai-learning-lab/.venv/lib/python3.13/site-packages/pandas/core/frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File ~/AI-Learning-Journey/my-ai-learning-lab/.venv/lib/python3.13/site-packages/pandas/core/indexes/base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'hour'
