# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
BASE_PATH = "../../data_collection/"
df = pd.read_csv(BASE_PATH + "amazon_delivery.csv")

# %%
sns.scatterplot(x=df["Traffic"], y=df["Delivery_Time"])
plt.show()

# %%
sns.scatterplot(x=df["Agent_Rating"], y=df["Delivery_Time"])
plt.show()

# %%
sns.boxplot(x=df["Weather"], y=df["Delivery_Time"])
plt.show()
