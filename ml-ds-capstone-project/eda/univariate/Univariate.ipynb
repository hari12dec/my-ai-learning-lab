# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
BASE_PATH = "../../data_collection/"
df = pd.read_csv(BASE_PATH + "amazon_delivery.csv")

# %%
df
# Out:
#             Order_ID  Agent_Age  Agent_Rating  Store_Latitude  \
# 0      ialx566343618         37           4.9       22.745049
# 1      akqg208421122         34           4.5       12.913041
# 2      njpu434582536         23           4.4       12.914264
# 3      rjto796129700         38           4.7       11.003669
# 4      zguw716275638         32           4.6       12.972793
# ...              ...        ...           ...             ...
# 43734  jlxf819993117         30           4.8       26.902328
# 43735  aevx342135787         21           4.6        0.000000
# 43736  xnek760674819         30           4.9       13.022394
# 43737  cynl434665991         20           4.7       11.001753
# 43738  nsyz997960170         23           4.9       23.351058
#
#        Store_Longitude  Drop_Latitude  Drop_Longitude  Order_Date Order_Time  \
# 0            75.892471      22.765049       75.912471  2022-03-19   11:30:00
# ...

# %%
# - Delivery time ranges from 10 to 250 minutes, with most values between 30–80 minutes.
# - Distribution is right-skewed, indicating presence of high-delay outliers.
# - Traffic is mostly Medium, with fewer High traffic cases.
# - Weather is mostly Clear, making the dataset slightly imbalanced.
# - No major issues in latitude/longitude values.
# - Some missing values observed in Traffic column.

# %%
sns.histplot(df["Delivery_Time"], bins=30)
plt.show()

# %%
sns.boxplot(x=df["Delivery_Time"])
# Out:
# <Axes: xlabel='Delivery_Time'>

# %%
sns.countplot(x=df["Traffic"])
# Out:
# <Axes: xlabel='Traffic', ylabel='count'>

# %%
sns.countplot(x=df["Weather"])
# Out:
# <Axes: xlabel='Weather', ylabel='count'>

# %%
sns.countplot(x=df["Agent_Age"])
# Out:
# <Axes: xlabel='Agent_Age', ylabel='count'>
