# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
BASE_PATH = "../data_collection/"
df = pd.read_csv(BASE_PATH + "prep_amazon_delivery_1.csv")

# %%
df.corr(numeric_only=True)
# Out:
#                        Agent_Age  Agent_Rating   Traffic  Delivery_Duration  \
# Agent_Age               1.000000     -0.117511  0.001178           0.258561
# Agent_Rating           -0.117511      1.000000 -0.069129          -0.307586
# Traffic                 0.001178     -0.069129  1.000000           0.353987
# Delivery_Duration       0.258561     -0.307586  0.353987           1.000000
# Weather_Fog            -0.009615      0.027152  0.005496           0.101744
# Weather_Sandstorms     -0.001368     -0.030693  0.000505          -0.014397
# Weather_Stormy          0.005236     -0.029885 -0.010662          -0.014782
# Weather_Sunny           0.005585      0.033843  0.003157          -0.180017
# Weather_Windy          -0.003818     -0.024916  0.005030          -0.010774
# Vehicle_scooter        -0.004180      0.022663  0.002943          -0.117010
# Vehicle_van             0.005085      0.013420  0.005918          -0.049884
# ...

# %%
sns.scatterplot(x=df["distance_km"], y=df["Delivery_Duration"])
# Out:
# <Axes: xlabel='distance_km', ylabel='Delivery_Duration'>

# %%
sns.boxplot(x=df["hour"], y=df["Delivery_Duration"])
# Out:
# <Axes: xlabel='hour', ylabel='Delivery_Duration'>

# %%
sns.boxplot(x=df["is_peak"], y=df["Delivery_Duration"])
# Out:
# <Axes: xlabel='is_peak', ylabel='Delivery_Duration'>

# %%
sns.boxplot(x=df["Agent_Age"], y=df["Delivery_Duration"])
# Out:
# <Axes: xlabel='Agent_Age', ylabel='Delivery_Duration'>

# %%
# import seaborn as sns
# sns.pairplot(df)
