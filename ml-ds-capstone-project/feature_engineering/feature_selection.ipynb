# %%
import pandas as pd
from feature_selection.SelectKRegression import selectKRegressionResult
from feature_selection import RFE_Regression
from feature_reduction import lda_regression
from feature_reduction import pca_regression

# %%
BASE_PATH = "../data_collection/"
dataset1 = pd.read_csv(BASE_PATH + "prep_amazon_delivery_1.csv")

selectKResult = selectKRegressionResult(dataset1, "Delivery_Duration", k=7)
print(selectKResult)
# Out:
# Selected Features (SelectK): ['Agent_Age', 'Agent_Rating', 'Traffic', 'hour_sin', 'is_peak', 'peak_weight', 'Category_Grocery']
# Final Features (after adding important): ['hour_sin', 'Agent_Age', 'Category_Grocery', 'peak_weight', 'distance_x_peak', 'is_peak', 'Traffic', 'dist_x_traffic', 'distance_km', 'Area_Urban', 'Weather_Sunny', 'Agent_Rating']
#                  RFR       GBR       XGB    Linear      SVMl     SVMnl  \
# Regression  0.707908  0.706527  0.705735  0.544557  0.539544  0.602225
#
#             Decision    Random
# Regression   0.41156  0.663999

# %%
# rfeResult = RFE_Regression.rfe_regression_result(dataset1, 'Delivery_Duration')
# rfeResult

# %%
# ldaResult = lda_regression.lda_regression_result(dataset1, 'Delivery_Duration')
# ldaResult

# %%
# pcaResult = pca_regression.pca_regression_result(dataset1, 'Delivery_Duration')
# pcaResult
