# %%
import pca_classification

# %%
pca_classification_result = pca_classification.pca_ClassificationResult()
pca_classification_result
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 pca_classification_result = pca_classification.pca_ClassificationResult()
#       2 pca_classification_result
#
# File ~/AI-Learning-Journey/my-ai-learning-lab/adv-machine-learning/PCA/pca_classification.py:129, in pca_ClassificationResult()
#     126 acclog, accsvml, accsvmnl, accknn, accnav, accdes, accrf = [], [], [], [], [], [], []
#     128 # Logistic
# --> 129 _, acc, _, _, _, _ = logistic(X_train, y_train, X_test, y_test)
#     130 acclog.append(acc)
#     132 # SVM Linear
#
# File ~/AI-Learning-Journey/my-ai-learning-lab/adv-machine-learning/PCA/pca_classification.py:50, in logistic(X_train, y_train, X_test, y_test)
#      48 def logistic(X_train, y_train, X_test, y_test):
#      49     classifier = LogisticRegression(random_state=0)
# ---> 50     classifier.fit(X_train, y_train)
# ...
