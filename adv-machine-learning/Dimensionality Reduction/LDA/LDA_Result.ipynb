# %%
import LDA_Classification
# Out:
#            Model  Accuracy
# 0       Logistic       1.0
# 1     SVM Linear       1.0
# 2        SVM RBF       1.0
# 3            KNN       1.0
# 4    Naive Bayes       1.0
# 5  Decision Tree       1.0
# 6  Random Forest       1.0

# %%
LDA_Classification.lda_classification_result()
# Out:
#            Model  Accuracy
# 0       Logistic       1.0
# 1     SVM Linear       1.0
# 2        SVM RBF       1.0
# 3            KNN       1.0
# 4    Naive Bayes       1.0
# 5  Decision Tree       1.0
# 6  Random Forest       1.0
