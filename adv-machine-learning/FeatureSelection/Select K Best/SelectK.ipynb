# %%
import SelectkClassification
import SelectkRegression

# %%
classificationResult = SelectkClassification.selectk_ClassificationResult()
classificationResult
# Out:
#           Logistic  SVMl SVMnl   KNN Naive Decision Random
# ChiSquare     0.94  0.94  0.95  0.89  0.83     0.96   0.95

# %%
regressionResult = SelectkRegression.selectKRegressionResult()
regressionResult
# Out:
#              Linear      SVMl     SVMnl  Decision    Random
# ChiSquare  0.551985  0.545395  0.749654  0.696181  0.836806
