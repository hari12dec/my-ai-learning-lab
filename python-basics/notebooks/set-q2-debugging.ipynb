# %%
#1.Find the error in the following Python code:
import math
print(math.sqrt(16)) #typo in math
# Out:
# 4.0

# %%
#2.Find the error in the following Python code:
def my_function():
    x = 10 #it should be inside function
    x += 5
    print(x)

my_function()
# Out:
# 15

# %%
#3.x = 5
if x == 10: # '==' for comparison
    print("x is 10")
# Out:
# x is 10

# %%
#4.
numbers = [5, 3, 8, 2]
print(numbers.sort()) #sort is the function
numbers.sort()
print(numbers)
# Out:
# None
# [2, 3, 5, 8]

# %%
#5.
def square(n):
    return n * n #return statement added

print(square(4))
# Out:
# 16

# %%
#6.
my_tuple = (1, 2, 3)
my_tuple[1] = 5
# tuple is immutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 3
#       1 #6.
#       2 my_tuple = (1, 2, 3)
# ----> 3 my_tuple[1] = 5
#
# TypeError: 'tuple' object does not support item assignment

# %%
#7.
name = "Alice"
age = 26
print("My name is %s and I am %d years old" % (name, age)) #age is missed in argument
# Out:
# My name is Alice and I am 26 years old

# %%
#8.
a = [1, 2, 3]
b = [1, 2, 3]
if a is b:
    print("Lists are equal")

# %%
#9.
for i in range(5, 1, -1): # range in reverse order, so we can add stepper in negative
    print(i)
# Out:
# 5
# 4
# 3
# 2

# %%
#10.
student = {"name": "John", "age": 20}
print(student["name"]) # name is the key value so it should be string
# Out:
# John
