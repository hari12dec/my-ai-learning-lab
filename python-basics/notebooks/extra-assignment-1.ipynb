# %%
print("HOPE AI")
# Out:
# HOPE AI

# %%
#Buy Input
input("Enter your institute name? :")
# Out:
# Enter your institute name? : Hope
# 'Hope'

# %%
#Buy inputs
userName = input("Enter your name:")
userAge = input("Enter your age:")
userSchoolName = input("Enter your school name:")
userDegree = input("Enter your degree:")

print(userName)
print(userAge)
print(userSchoolName)
print(userDegree)
# Out:
# Enter your name: Hari
# Enter your age: 35
# Enter your school name: SHSS
# Enter your degree: BE
# Hari
# 35
# SHSS
# BE

# %%
#Addition
num1 = int(input("Num 1="))
num2 = int(input("Num 2="))
print(f"Add = {num1 + num2}")
# Out:
# Num 1= 10
# Num 2= 10
# Add = 20

# %%
#Subtraction
num1 = int(input("Num 1="))
num2 = int(input("Num 2="))
print(f"Sub = {num1 - num2}")
# Out:
# Num 1= 10
# Num 2= 10
# Sub = 0

# %%
#Multiplication
num1 = int(input("Num 1="))
num2 = int(input("Num 2="))
print(f"Mul = {num1 * num2}")
# Out:
# Num 1= 10
# Num 2= 10
# Mul = 100

# %%
#Divison
num1 = int(input("Num 1="))
num2 = int(input("Num 2="))
print(f"Div = {num1 / num2}")
# Out:
# Num 1= 10
# Num 2= 10
# Div = 1.0

# %%
#Floor Div
num1 = int(input("Num 1="))
num2 = int(input("Num 2="))
print(f"Floor Div = {int(num1 / num2)}")
# Out:
# Num 1= 10
# Num 2= 10
# Floor Div = 1

# %%
#Modulo
num1 = int(input("Num 1="))
num2 = int(input("Num 2="))
print(f"Modul0 = {num1 % num2}")
# Out:
# Num 1= 10
# Num 2= 10
# Modul0 = 0

# %%
#Power
num1 = int(input("Num 1="))
num2 = int(input("Num 2="))
print(f"Power = {pow(num1, num2)}")
# Out:
# Num 1= 2
# Num 2= 2
# Power = 4
