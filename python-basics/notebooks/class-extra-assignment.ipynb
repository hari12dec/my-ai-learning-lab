# %%
# Create a class and function, and list out the items in the list
class AISubFields:
    def SubfieldsInAI():
        aiSubFields = ["Machine Learning", "Neural Networks", "Vision", "Robotics", "Speech Processing", "Natural Language Processing"]
        print("Sub-fields in AI are:")
        for subField in aiSubFields:
            print(subField)
    
AISubFields.SubfieldsInAI()
# Out:
# Sub-fields in AI are:
# Machine Learning
# Neural Networks
# Vision
# Robotics
# Speech Processing
# Natural Language Processing

# %%
# Create a function that checks whether the given number is Odd or Even
# Enter a number: 52452
# 52452 is Even number
class OddorEven:
    def findOddorEven():
        num1 = int(input("Enter a number:"))
        if num1 % 2 == 0:
            output = f"{num1} is Even number"
        else:
            output = f"{num1} is Odd number"
        return output

# %%
OddorEven.findOddorEven()
# Out:
# Enter a number: 52452
# '52452 is Even number'

# %%
# Create a function that tells elegibility of marriage for male and female according to their age limit like 21 for male and 18 for female
# Your Gender:Male
# Your Age:20
# NOT ELIGIBLE

class MarriageEligibilityCheck:
    def marriageEligibilityCheck(gender, age):
        print(f"Your Gender: {gender}")
        print(f"Your age: {age}")
    
        if gender.lower() == "male" and age >= 21 or gender.lower() == "female" and age >= 18:
            output = "ELIGIBLE"
        else:
            output = "NOT ELIGIBLE"
        print(output)

# %%
MarriageEligibilityCheck.marriageEligibilityCheck("male", 20)
# Out:
# Your Gender: male
# Your age: 20
# NOT ELIGIBLE

# %%
#### calculate the percentage of your 10th mark

# Subject1= 98
# Subject2= 87
# Subject3= 95
# Subject4= 95
# Subject5= 93
# Total : 468
# Percentage : 93.60000000000001

class PercentageCalculator:
    def findPercentage():
        Subject1 = int(input("Subject1="))
        Subject2 = int(input("Subject2="))
        Subject3 = int(input("Subject3="))
        Subject4 = int(input("Subject4="))
        Subject5 = int(input("Subject5="))
    
        listOfSubject = [Subject1, Subject2, Subject3, Subject4, Subject5]
        total = sum(listOfSubject)
        percentage = total/len(listOfSubject)
        return total, percentage

# %%
result = PercentageCalculator.findPercentage()
print(f"Total: {result[0]}")
print(f"Percentage: {result[1]}")
# Out:
# Subject1= 98
# Subject2= 87
# Subject3= 95
# Subject4= 95
# Subject5= 93
# Total: 468
# Percentage: 93.6

# %%
#print area and perimeter of triangle using class and functions

# Height:32
# Breadth:34
# Area formula: (Height*Breadth)/2
# Area of Triangle: 544.0

# Height1:2
# Height2:4
# Breadth:4
# Perimeter formula: Height1+Height2+Breadth
# Perimeter of Triangle: 10

class TriangeHelper:
    def findAreaOfTriangle(height, breadth):
        print(f"Height:{height}")
        print(f"Breadth:{breadth}")
        print("Area formula: (Height*Breadth)/2")
        area = (height * breadth) / 2
        print(f"Area of Triangle: {area}")
        return
        
    def findPerimeterOfTriangle(height, anotherheight, breadth):
        print(f"Height1:{height}")
        print(f"Height2:{anotherheight}")
        print(f"Breadth:{breadth}")
        print("Perimeter formula: Height1+Height2+Breadth")
        perimeter = height + anotherheight + breadth
        print(f"Perimeter of Triangle: {perimeter}")
        return

# %%
TriangeHelper.findAreaOfTriangle(32, 34)
TriangeHelper.findPerimeterOfTriangle(2, 4, 4)
# Out:
# Height:32
# Breadth:34
# Area formula: (Height*Breadth)/2
# Area of Triangle: 544.0
# Height1:2
# Height2:4
# Breadth:4
# Perimeter formula: Height1+Height2+Breadth
# Perimeter of Triangle: 10
