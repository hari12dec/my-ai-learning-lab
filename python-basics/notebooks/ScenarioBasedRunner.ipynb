# %%
from ScenarioBasedOne import ScenarioBased

# %%
ScenarioBased.voterEligibility()

# %%
ScenarioBased.findTheLargestNumber()

# %%
ScenarioBased.detemineBonus(57823)

# %%
ScenarioBased.findOddorEvenNumber(67)

# %%
ScenarioBased.textProcessReverse()

# %%
ScenarioBased.checkStudentScoring()

# %%
result = ScenarioBased.offerCalculation(105)
print(f"Eligible for discount, Final billed amount: ${result[1]}" if result[0] else "Not Eligible for discount")

# %%
ScenarioBased.bankingWithdrawalProcess()

# %%
ScenarioBased.findLeapYear(2000)

# %%
ScenarioBased.filterEvenNumber()

# %%
from ScenarioBasedTwo import ScenarioBased
ScenarioBased.checkAnagram("rose", "ossr")
# Out:
# Given strings are NOT Anagrams
